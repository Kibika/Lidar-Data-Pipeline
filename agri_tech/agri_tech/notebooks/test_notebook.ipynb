# %%
# not yet functioning seamlessly
#TODO: Add filename.txt data to package
# pip install agri-tech==0.1.0
# Out:
# WARNING: Ignoring invalid distribution -ython-dateutil (/opt/miniconda/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -heel (/opt/miniconda/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -ython-dateutil (/opt/miniconda/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -heel (/opt/miniconda/lib/python3.9/site-packages)
# Requirement already satisfied: agri-tech==0.1.0 in /opt/miniconda/lib/python3.9/site-packages (0.1.0)
# WARNING: Ignoring invalid distribution -ython-dateutil (/opt/miniconda/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -heel (/opt/miniconda/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -ython-dateutil (/opt/miniconda/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -heel (/opt/miniconda/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -ython-dateutil (/opt/miniconda/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -heel (/opt/miniconda/lib/python3.9/site-packages)
# Note: you may need to restart the kernel to use updated packages.

# %%
# import agri_tech

# %%
from agri_tech import Lidar

# %%
method = Lidar()

# %%
method.region()
# Out:
# interactive(children=(Dropdown(description='x', options=('AK_BrooksCamp_2012/', 'AK_Coastal_2009/', 'AK_Fairba…
# Text(value='AK_BrooksCamp_2012/')

# %%
method.ept_json()
# Out:
# 'https://s3-us-west-2.amazonaws.com/usgs-lidar-public/IA_FullState/ept.json'

# %%
method.pipeline(xmin = -93.756155,xmax = -93.747334, ymin = 41.918015, ymax = 41.921429)
# Out:
# '([-10436887.43333523, -10435905.484106943], [5148706.389047224, 5149217.145836504])'

# %%
method.run_pipeline()
# Out:
# 'spatial_subset.geojson'

# %%
method.geodf('spatial_subset.geojson')
# Out:
#        elevation_m                           geometry
# 0          318.490  POINT (-10435906.070 5149216.030)
# 1          318.370  POINT (-10435907.330 5149215.640)
# 2          318.410  POINT (-10435908.700 5149215.960)
# 3          318.150  POINT (-10435921.570 5149216.780)
# 4          318.290  POINT (-10435920.250 5149216.480)
# ...            ...                                ...
# 403326     318.040  POINT (-10435991.800 5149213.980)
# 403327     318.100  POINT (-10435968.960 5149217.050)
# 403328     317.770  POINT (-10436002.880 5149215.030)
# 403329     317.880  POINT (-10436005.220 5149214.710)
# 403330     317.950  POINT (-10435990.830 5149216.790)
#
# [403331 rows x 2 columns]

# %%
method.plot_raster('spatial_subset.tif')

# %%
method.plot3d()
